# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([6,7,8,,9,10])
arr1
# Out:
#   Cell In[2], line 2
#     arr2 = np.array(6,7,8,,9,10)
#                           ^
# SyntaxError: invalid syntax
